# %%
# Created by Noel Naughton (nnaught2@illinois.edu) on May 10, 2019
# Import numerical results from sensitivity study and generate sensitivity results
# 

# import libraries
import numpy as np
import pandas as pd
import math
from SALib.sample import saltelli
from SALib.analyze import sobol

problem = { 'num_vars': 9,

            'bounds': [[10e-6, 80e-6 ], # diameter
                      [0.70  , 0.95  ], # volume fraction
                      [10e-6 , 100e-6], # permeability
                      [0.5e-9, 2.5e-9], # Din
                      [0.5e-9, 2.5e-9], # Dex
                      [0.0200, 0.040 ], # T2in
                      [0.0800, 0.140 ], # T2ex
                      [0.0200, 0.080 ], # Gradient
                      [0.0100, 0.750]],  # Diffusion Time

            'names': ['Diameter', 
                        'Volume Fraction', 
                        'Permeability', 
                        'Intracellular Diffusion', 
                        'Extracellular Diffusion', 
                        'Intracellular $T_2$', 
                        'Extracellular $T_2$',
                        'Gradient Strength',
                        'Diffusion Time']
            }

param_values = saltelli.sample(problem, 5000)

filename = 'sensitivity_results.csv'
df = pd.read_csv(filename,header=[0, 1], skipinitialspace=True)

DTI_indices = df['DTI Metrics'][['FA','MD','RD','L1','L2','L3']]

Si = { }
for i, j in enumerate( DTI_indices.columns):
    print('Sensitivity Indices for %s' % j)
    Si[j] = sobol.analyze(problem, DTI_indices.values[:,i], print_to_console=True)
    print(' ')
    print('_____________________________________________________________________________________')
# Out:
# Sensitivity Indices for FA
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.234919 0.031099 0.509869 0.028327
# Volume Fraction 0.000528 0.017970 0.171519 0.015875
# Permeability 0.094924 0.013981 0.159524 0.014642
# Intracellular Diffusion -0.008213 0.017637 0.220641 0.020549
# Extracellular Diffusion 0.000611 0.017797 0.205579 0.028094
# Intracellular $T_2$ 0.000519 0.008678 0.067393 0.010495
# Extracellular $T_2$ 0.001586 0.003588 0.006184 0.004222
# Gradient Strength 0.024269 0.027330 0.378900 0.032921
# Diffusion Time 0.035300 0.029624 0.400464 0.036216
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.062640 0.042700
# Diameter Permeability 0.007635 0.040602
# Diameter Intracellular Diffusion 0.029074 0.044518
# Diameter Extracellular Diffusion 0.005372 0.041802
# Diameter Intracellular $T_2$ 0.012343 0.039314
# Diameter Extracellular $T_2$ 0.009574 0.038968
# Diameter Gradient Strength 0.027497 0.043807
# Diameter Diffusion Time 0.032761 0.046517
# Volume Fraction Permeability 0.030633 0.023588
# Volume Fraction Intracellular Diffusion 0.032694 0.025814
# Volume Fraction Extracellular Diffusion 0.019849 0.024805
# Volume Fraction Intracellular $T_2$ 0.021780 0.024740
# Volume Fraction Extracellular $T_2$ 0.025326 0.023430
# Volume Fraction Gradient Strength 0.024691 0.023317
# Volume Fraction Diffusion Time 0.013644 0.024848
# Permeability Intracellular Diffusion 0.006417 0.020598
# Permeability Extracellular Diffusion 0.007119 0.019888
# Permeability Intracellular $T_2$ -0.001234 0.020415
# Permeability Extracellular $T_2$ -0.000831 0.020829
# Permeability Gradient Strength -0.008834 0.021014
# Permeability Diffusion Time 0.010984 0.022702
# Intracellular Diffusion Extracellular Diffusion 0.006434 0.025040
# Intracellular Diffusion Intracellular $T_2$ 0.001719 0.025299
# Intracellular Diffusion Extracellular $T_2$ 0.004466 0.024789
# Intracellular Diffusion Gradient Strength 0.019583 0.026612
# Intracellular Diffusion Diffusion Time 0.014667 0.026137
# Extracellular Diffusion Intracellular $T_2$ -0.003873 0.019960
# Extracellular Diffusion Extracellular $T_2$ -0.008246 0.020839
# Extracellular Diffusion Gradient Strength 0.016690 0.024787
# Extracellular Diffusion Diffusion Time 0.017196 0.024415
# Intracellular $T_2$ Extracellular $T_2$ 0.004637 0.014387
# Intracellular $T_2$ Gradient Strength 0.006506 0.015320
# Intracellular $T_2$ Diffusion Time 0.000823 0.014675
# Extracellular $T_2$ Gradient Strength -0.004616 0.004801
# Extracellular $T_2$ Diffusion Time -0.004004 0.005857
# Gradient Strength Diffusion Time 0.090974 0.037846
#
# _____________________________________________________________________________________
# Sensitivity Indices for MD
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.119632 0.019630 0.239019 0.015960
# Volume Fraction 0.013353 0.014803 0.111311 0.009959
# Permeability 0.044500 0.012664 0.102998 0.010019
# Intracellular Diffusion 0.078054 0.020792 0.246329 0.016072
# Extracellular Diffusion 0.077505 0.019773 0.229148 0.015179
# Intracellular $T_2$ 0.002249 0.007088 0.034635 0.005670
# Extracellular $T_2$ 0.000478 0.001570 0.002683 0.001472
# Gradient Strength 0.122386 0.026719 0.433576 0.034181
# Diffusion Time 0.132311 0.024888 0.409586 0.038206
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.004660 0.023208
# Diameter Permeability -0.008016 0.025839
# Diameter Intracellular Diffusion -0.001062 0.026147
# Diameter Extracellular Diffusion -0.008119 0.024778
# Diameter Intracellular $T_2$ -0.002726 0.023757
# Diameter Extracellular $T_2$ -0.011546 0.024010
# Diameter Gradient Strength -0.006129 0.022849
# Diameter Diffusion Time 0.001205 0.023323
# Volume Fraction Permeability -0.006604 0.019323
# Volume Fraction Intracellular Diffusion -0.002248 0.018166
# Volume Fraction Extracellular Diffusion 0.006413 0.019834
# Volume Fraction Intracellular $T_2$ -0.007086 0.018906
# Volume Fraction Extracellular $T_2$ -0.005081 0.018357
# Volume Fraction Gradient Strength -0.011413 0.019947
# Volume Fraction Diffusion Time -0.009419 0.019536
# Permeability Intracellular Diffusion 0.008017 0.016743
# Permeability Extracellular Diffusion -0.002788 0.015981
# Permeability Intracellular $T_2$ 0.004163 0.015620
# Permeability Extracellular $T_2$ 0.001572 0.015898
# Permeability Gradient Strength -0.000561 0.015433
# Permeability Diffusion Time -0.000197 0.015537
# Intracellular Diffusion Extracellular Diffusion -0.005489 0.027749
# Intracellular Diffusion Intracellular $T_2$ -0.008344 0.028612
# Intracellular Diffusion Extracellular $T_2$ -0.007097 0.029197
# Intracellular Diffusion Gradient Strength 0.021068 0.028381
# Intracellular Diffusion Diffusion Time 0.012368 0.029273
# Extracellular Diffusion Intracellular $T_2$ 0.022000 0.025631
# Extracellular Diffusion Extracellular $T_2$ 0.018114 0.025430
# Extracellular Diffusion Gradient Strength 0.041819 0.025071
# Extracellular Diffusion Diffusion Time 0.021784 0.027666
# Intracellular $T_2$ Extracellular $T_2$ -0.002733 0.011747
# Intracellular $T_2$ Gradient Strength -0.000830 0.011659
# Intracellular $T_2$ Diffusion Time -0.002730 0.010885
# Extracellular $T_2$ Gradient Strength -0.002226 0.003500
# Extracellular $T_2$ Diffusion Time 0.000183 0.003567
# Gradient Strength Diffusion Time 0.097305 0.036309
#
# _____________________________________________________________________________________
# Sensitivity Indices for RD
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.118368 0.019793 0.234070 0.015829
# Volume Fraction 0.012331 0.013497 0.107448 0.009626
# Permeability 0.040878 0.011699 0.096885 0.008066
# Intracellular Diffusion 0.078448 0.016389 0.245938 0.017465
# Extracellular Diffusion 0.080234 0.020787 0.234576 0.015321
# Intracellular $T_2$ 0.001150 0.007227 0.031600 0.005458
# Extracellular $T_2$ 0.000219 0.001480 0.002529 0.001672
# Gradient Strength 0.130157 0.026566 0.447855 0.034551
# Diffusion Time 0.123702 0.025989 0.405046 0.036248
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.005071 0.024942
# Diameter Permeability -0.006607 0.024878
# Diameter Intracellular Diffusion 0.000010 0.027654
# Diameter Extracellular Diffusion -0.007306 0.024236
# Diameter Intracellular $T_2$ -0.002546 0.024461
# Diameter Extracellular $T_2$ -0.010300 0.024453
# Diameter Gradient Strength -0.004726 0.023864
# Diameter Diffusion Time 0.000552 0.024251
# Volume Fraction Permeability -0.005683 0.017568
# Volume Fraction Intracellular Diffusion -0.001496 0.017181
# Volume Fraction Extracellular Diffusion 0.008054 0.018787
# Volume Fraction Intracellular $T_2$ -0.005306 0.017856
# Volume Fraction Extracellular $T_2$ -0.003298 0.017384
# Volume Fraction Gradient Strength -0.009856 0.019732
# Volume Fraction Diffusion Time -0.007867 0.017431
# Permeability Intracellular Diffusion 0.007676 0.016721
# Permeability Extracellular Diffusion -0.002703 0.017045
# Permeability Intracellular $T_2$ 0.003970 0.016102
# Permeability Extracellular $T_2$ 0.001578 0.016474
# Permeability Gradient Strength -0.000331 0.015739
# Permeability Diffusion Time -0.000676 0.017812
# Intracellular Diffusion Extracellular Diffusion -0.006004 0.026702
# Intracellular Diffusion Intracellular $T_2$ -0.008642 0.024802
# Intracellular Diffusion Extracellular $T_2$ -0.007435 0.025747
# Intracellular Diffusion Gradient Strength 0.021107 0.027381
# Intracellular Diffusion Diffusion Time 0.011987 0.026655
# Extracellular Diffusion Intracellular $T_2$ 0.021288 0.024205
# Extracellular Diffusion Extracellular $T_2$ 0.017607 0.025047
# Extracellular Diffusion Gradient Strength 0.042850 0.023513
# Extracellular Diffusion Diffusion Time 0.021523 0.029604
# Intracellular $T_2$ Extracellular $T_2$ -0.002918 0.009333
# Intracellular $T_2$ Gradient Strength 0.000028 0.011990
# Intracellular $T_2$ Diffusion Time -0.003494 0.010650
# Extracellular $T_2$ Gradient Strength -0.002216 0.003523
# Extracellular $T_2$ Diffusion Time 0.000347 0.003459
# Gradient Strength Diffusion Time 0.101276 0.035515
#
# _____________________________________________________________________________________
# Sensitivity Indices for L1
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.042968 0.012702 0.117822 0.011047
# Volume Fraction 0.009577 0.012533 0.104679 0.010799
# Permeability 0.015288 0.010072 0.073776 0.010329
# Intracellular Diffusion 0.110449 0.024940 0.316217 0.017154
# Extracellular Diffusion 0.106581 0.020226 0.317609 0.016646
# Intracellular $T_2$ -0.001620 0.005978 0.029328 0.006964
# Extracellular $T_2$ -0.000203 0.001876 0.002834 0.002907
# Gradient Strength 0.131136 0.028677 0.526436 0.037396
# Diffusion Time 0.106917 0.029567 0.459207 0.033641
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction -0.005258 0.018090
# Diameter Permeability -0.005520 0.018275
# Diameter Intracellular Diffusion -0.004038 0.018546
# Diameter Extracellular Diffusion -0.002530 0.019169
# Diameter Intracellular $T_2$ -0.004224 0.018346
# Diameter Extracellular $T_2$ -0.007658 0.017918
# Diameter Gradient Strength -0.007686 0.019083
# Diameter Diffusion Time 0.000016 0.018164
# Volume Fraction Permeability -0.005147 0.018076
# Volume Fraction Intracellular Diffusion 0.007518 0.018786
# Volume Fraction Extracellular Diffusion 0.012326 0.017551
# Volume Fraction Intracellular $T_2$ -0.001960 0.016852
# Volume Fraction Extracellular $T_2$ -0.000897 0.016719
# Volume Fraction Gradient Strength -0.009374 0.019580
# Volume Fraction Diffusion Time -0.009064 0.017841
# Permeability Intracellular Diffusion 0.005815 0.015852
# Permeability Extracellular Diffusion 0.001237 0.015308
# Permeability Intracellular $T_2$ 0.005862 0.013680
# Permeability Extracellular $T_2$ 0.004125 0.013699
# Permeability Gradient Strength -0.001177 0.013574
# Permeability Diffusion Time 0.000514 0.013956
# Intracellular Diffusion Extracellular Diffusion 0.008452 0.032775
# Intracellular Diffusion Intracellular $T_2$ 0.002679 0.031373
# Intracellular Diffusion Extracellular $T_2$ 0.005249 0.031513
# Intracellular Diffusion Gradient Strength 0.038320 0.030974
# Intracellular Diffusion Diffusion Time 0.035099 0.031705
# Extracellular Diffusion Intracellular $T_2$ 0.022999 0.032134
# Extracellular Diffusion Extracellular $T_2$ 0.016760 0.031820
# Extracellular Diffusion Gradient Strength 0.050346 0.029234
# Extracellular Diffusion Diffusion Time 0.025420 0.028004
# Intracellular $T_2$ Extracellular $T_2$ -0.002887 0.010045
# Intracellular $T_2$ Gradient Strength 0.001096 0.010917
# Intracellular $T_2$ Diffusion Time -0.004560 0.010009
# Extracellular $T_2$ Gradient Strength -0.001958 0.004160
# Extracellular $T_2$ Diffusion Time 0.000805 0.004918
# Gradient Strength Diffusion Time 0.128860 0.045125
#
# _____________________________________________________________________________________
# Sensitivity Indices for L2
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.002142 0.011220 0.085618 0.013731
# Volume Fraction 0.004951 0.013679 0.114792 0.014025
# Permeability 0.002956 0.009790 0.062757 0.013121
# Intracellular Diffusion 0.133229 0.028370 0.388186 0.021233
# Extracellular Diffusion 0.118295 0.025868 0.366838 0.019267
# Intracellular $T_2$ -0.004263 0.006759 0.032973 0.007537
# Extracellular $T_2$ -0.000616 0.002001 0.003512 0.002837
# Gradient Strength 0.107195 0.035038 0.543990 0.039788
# Diffusion Time 0.076478 0.029497 0.474125 0.037002
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction -0.001913 0.016047
# Diameter Permeability -0.003244 0.016296
# Diameter Intracellular Diffusion 0.010874 0.016956
# Diameter Extracellular Diffusion 0.003220 0.016664
# Diameter Intracellular $T_2$ -0.003064 0.015908
# Diameter Extracellular $T_2$ -0.002777 0.016534
# Diameter Gradient Strength -0.005145 0.017605
# Diameter Diffusion Time 0.004140 0.015895
# Volume Fraction Permeability 0.002045 0.018900
# Volume Fraction Intracellular Diffusion 0.026375 0.021091
# Volume Fraction Extracellular Diffusion 0.018990 0.018963
# Volume Fraction Intracellular $T_2$ 0.005810 0.017025
# Volume Fraction Extracellular $T_2$ 0.006544 0.017401
# Volume Fraction Gradient Strength -0.002590 0.019238
# Volume Fraction Diffusion Time -0.004584 0.018073
# Permeability Intracellular Diffusion 0.004903 0.016353
# Permeability Extracellular Diffusion 0.006228 0.013518
# Permeability Intracellular $T_2$ 0.006862 0.015233
# Permeability Extracellular $T_2$ 0.006325 0.015448
# Permeability Gradient Strength -0.001872 0.013889
# Permeability Diffusion Time 0.003929 0.016386
# Intracellular Diffusion Extracellular Diffusion 0.023413 0.037314
# Intracellular Diffusion Intracellular $T_2$ 0.014496 0.035668
# Intracellular Diffusion Extracellular $T_2$ 0.018353 0.035932
# Intracellular Diffusion Gradient Strength 0.050700 0.033985
# Intracellular Diffusion Diffusion Time 0.051002 0.035373
# Extracellular Diffusion Intracellular $T_2$ 0.021217 0.034076
# Extracellular Diffusion Extracellular $T_2$ 0.012779 0.035187
# Extracellular Diffusion Gradient Strength 0.050536 0.032660
# Extracellular Diffusion Diffusion Time 0.026349 0.035623
# Intracellular $T_2$ Extracellular $T_2$ -0.001852 0.011580
# Intracellular $T_2$ Gradient Strength 0.002227 0.012579
# Intracellular $T_2$ Diffusion Time -0.004483 0.012787
# Extracellular $T_2$ Gradient Strength -0.001786 0.004337
# Extracellular $T_2$ Diffusion Time 0.000794 0.005518
# Gradient Strength Diffusion Time 0.138750 0.045288
#
# _____________________________________________________________________________________
# Sensitivity Indices for L3
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.116960 0.017852 0.230961 0.015077
# Volume Fraction 0.011430 0.013142 0.105348 0.009472
# Permeability 0.037342 0.013754 0.091677 0.008199
# Intracellular Diffusion 0.078396 0.019022 0.244589 0.018025
# Extracellular Diffusion 0.082488 0.020043 0.239280 0.016217
# Intracellular $T_2$ 0.000506 0.006813 0.029629 0.005057
# Extracellular $T_2$ -0.000030 0.001431 0.002439 0.001920
# Gradient Strength 0.137132 0.026044 0.460589 0.036478
# Diffusion Time 0.115193 0.024015 0.400004 0.039747
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.005964 0.022737
# Diameter Permeability -0.005268 0.024672
# Diameter Intracellular Diffusion 0.001044 0.024877
# Diameter Extracellular Diffusion -0.006506 0.023211
# Diameter Intracellular $T_2$ -0.002253 0.024356
# Diameter Extracellular $T_2$ -0.009140 0.024633
# Diameter Gradient Strength -0.003269 0.024857
# Diameter Diffusion Time 0.000142 0.023874
# Volume Fraction Permeability -0.004537 0.020162
# Volume Fraction Intracellular Diffusion -0.000763 0.019168
# Volume Fraction Extracellular Diffusion 0.009653 0.020834
# Volume Fraction Intracellular $T_2$ -0.003510 0.019347
# Volume Fraction Extracellular $T_2$ -0.001511 0.019228
# Volume Fraction Gradient Strength -0.008270 0.018825
# Volume Fraction Diffusion Time -0.006302 0.019736
# Permeability Intracellular Diffusion 0.007318 0.019420
# Permeability Extracellular Diffusion -0.002569 0.018125
# Permeability Intracellular $T_2$ 0.003799 0.017444
# Permeability Extracellular $T_2$ 0.001575 0.017649
# Permeability Gradient Strength -0.000087 0.017285
# Permeability Diffusion Time -0.001141 0.019317
# Intracellular Diffusion Extracellular Diffusion -0.006447 0.027164
# Intracellular Diffusion Intracellular $T_2$ -0.008851 0.024966
# Intracellular Diffusion Extracellular $T_2$ -0.007710 0.025013
# Intracellular Diffusion Gradient Strength 0.021062 0.024144
# Intracellular Diffusion Diffusion Time 0.011567 0.027223
# Extracellular Diffusion Intracellular $T_2$ 0.020401 0.027696
# Extracellular Diffusion Extracellular $T_2$ 0.016923 0.028431
# Extracellular Diffusion Gradient Strength 0.043621 0.026931
# Extracellular Diffusion Diffusion Time 0.021087 0.026237
# Intracellular $T_2$ Extracellular $T_2$ -0.003215 0.010305
# Intracellular $T_2$ Gradient Strength 0.000710 0.011331
# Intracellular $T_2$ Diffusion Time -0.004276 0.010402
# Extracellular $T_2$ Gradient Strength -0.002184 0.003505
# Extracellular $T_2$ Diffusion Time 0.000513 0.003574
# Gradient Strength Diffusion Time 0.104692 0.038661
#
# _____________________________________________________________________________________
