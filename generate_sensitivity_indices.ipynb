# %%
"""
Created by Noel Naughton (nnaught2@illinois.edu) on May 10, 2019; Updated August 5, 2019
Imports numerical results from sensitivity study and generates sensitivity results

This cell generates the sensitivity indices for the PGSE sequence. The raw data is located in 
'sensitivity_results-PGSE.csv' and the imported dataframe contains other informatino regarding 
the numerical parameters used in the simulation. 
"""

# import libraries
import numpy as np
import pandas as pd
import math
from SALib.sample import saltelli
from SALib.analyze import sobol

problem_PGSE = { 'num_vars': 9,

           'bounds': [[10e-6, 80e-6 ], # diameter
                      [0.70  , 0.95  ], # volume fraction
                      [10e-6 , 100e-6], # permeability
                      [0.5e-9, 2.5e-9], # Din
                      [0.5e-9, 2.5e-9], # Dex
                      [0.0200, 0.040 ], # T2in
                      [0.0800, 0.140 ], # T2ex
                      [300e6 , 1200e6],  # b-value
                      [0.0100, 0.090]],  # Diffusion Time

            'names': ['Diameter', 
                        'Volume Fraction', 
                        'Permeability', 
                        'Intracellular Diffusion', 
                        'Extracellular Diffusion', 
                        'Intracellular $T_2$', 
                        'Extracellular $T_2$',
                        'B-Value',
                        'Diffusion Time']
            }

param_values = saltelli.sample(problem_PGSE, 5000)

filename = 'sensitivity_results-PGSE.csv'
df = pd.read_csv(filename,header=[0, 1], skipinitialspace=True)
DTI_indices = df['DTI Metrics'][['FA','MD','RD','L1','L2','L3']]

Si_PGSE = { }
for i, j in enumerate( DTI_indices.columns):
    print('Sensitivity Indices for %s' % j)
    Si_PGSE[j] = sobol.analyze(problem_PGSE, DTI_indices.values[:,i], print_to_console=True)
    print(' ')
    print('_____________________________________________________________________________________')
# Out:
# Sensitivity Indices for FA
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.652671 0.036246 0.741611 0.026945
# Volume Fraction 0.004021 0.008347 0.046033 0.003233
# Permeability 0.105172 0.012129 0.118672 0.005650
# Intracellular Diffusion 0.074319 0.013680 0.136438 0.010565
# Extracellular Diffusion 0.016170 0.005461 0.026371 0.001829
# Intracellular $T_2$ -0.000483 0.003895 0.012332 0.000965
# Extracellular $T_2$ -0.000179 0.000874 0.000579 0.000043
# B-Value 0.000468 0.001625 0.002715 0.000254
# Diffusion Time 0.032889 0.008407 0.042374 0.002748
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.022573 0.055039
# Diameter Permeability 0.005690 0.053487
# Diameter Intracellular Diffusion 0.045153 0.054555
# Diameter Extracellular Diffusion 0.006174 0.053221
# Diameter Intracellular $T_2$ 0.006532 0.052031
# Diameter Extracellular $T_2$ -0.000627 0.051498
# Diameter B-Value -0.000452 0.051190
# Diameter Diffusion Time -0.000315 0.053206
# Volume Fraction Permeability 0.003432 0.013788
# Volume Fraction Intracellular Diffusion 0.010388 0.013397
# Volume Fraction Extracellular Diffusion 0.005734 0.013994
# Volume Fraction Intracellular $T_2$ 0.003151 0.013535
# Volume Fraction Extracellular $T_2$ 0.003420 0.013698
# Volume Fraction B-Value 0.003400 0.013612
# Volume Fraction Diffusion Time 0.003617 0.013483
# Permeability Intracellular Diffusion 0.003240 0.019773
# Permeability Extracellular Diffusion -0.001728 0.018303
# Permeability Intracellular $T_2$ -0.000838 0.018315
# Permeability Extracellular $T_2$ -0.001086 0.018278
# Permeability B-Value -0.001303 0.018152
# Permeability Diffusion Time -0.000719 0.018990
# Intracellular Diffusion Extracellular Diffusion 0.004613 0.019967
# Intracellular Diffusion Intracellular $T_2$ 0.007152 0.019834
# Intracellular Diffusion Extracellular $T_2$ 0.005247 0.019832
# Intracellular Diffusion B-Value 0.005680 0.019787
# Intracellular Diffusion Diffusion Time 0.004377 0.019853
# Extracellular Diffusion Intracellular $T_2$ 0.000263 0.009021
# Extracellular Diffusion Extracellular $T_2$ -0.000455 0.009135
# Extracellular Diffusion B-Value -0.000111 0.009257
# Extracellular Diffusion Diffusion Time -0.000612 0.009370
# Intracellular $T_2$ Extracellular $T_2$ 0.000295 0.005786
# Intracellular $T_2$ B-Value 0.000398 0.005741
# Intracellular $T_2$ Diffusion Time -0.000336 0.005597
# Extracellular $T_2$ B-Value -0.000348 0.001573
# Extracellular $T_2$ Diffusion Time -0.000428 0.001564
# B-Value Diffusion Time 0.000149 0.002415
#
# _____________________________________________________________________________________
# Sensitivity Indices for MD
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.307797 0.024645 0.389627 0.020527
# Volume Fraction -0.001618 0.008691 0.052097 0.004019
# Permeability 0.062847 0.011333 0.075906 0.004116
# Intracellular Diffusion 0.364460 0.025791 0.456246 0.022795
# Extracellular Diffusion 0.100943 0.013734 0.130609 0.007972
# Intracellular $T_2$ 0.000115 0.004856 0.009711 0.000879
# Extracellular $T_2$ -0.000083 0.000925 0.000481 0.000042
# B-Value 0.002012 0.002450 0.003511 0.000279
# Diffusion Time 0.015233 0.007608 0.030195 0.002532
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.014278 0.032290
# Diameter Permeability 0.006066 0.031074
# Diameter Intracellular Diffusion 0.050313 0.031578
# Diameter Extracellular Diffusion 0.002912 0.032523
# Diameter Intracellular $T_2$ 0.004102 0.030321
# Diameter Extracellular $T_2$ 0.001080 0.030247
# Diameter B-Value 0.001018 0.030474
# Diameter Diffusion Time 0.000193 0.030395
# Volume Fraction Permeability 0.001980 0.013129
# Volume Fraction Intracellular Diffusion 0.010726 0.013739
# Volume Fraction Extracellular Diffusion 0.020467 0.012819
# Volume Fraction Intracellular $T_2$ 0.001392 0.013209
# Volume Fraction Extracellular $T_2$ 0.001584 0.013136
# Volume Fraction B-Value 0.001432 0.013307
# Volume Fraction Diffusion Time 0.001387 0.013401
# Permeability Intracellular Diffusion 0.008016 0.018719
# Permeability Extracellular Diffusion -0.004645 0.015087
# Permeability Intracellular $T_2$ -0.004125 0.014984
# Permeability Extracellular $T_2$ -0.003939 0.015101
# Permeability B-Value -0.003609 0.015101
# Permeability Diffusion Time -0.004068 0.015183
# Intracellular Diffusion Extracellular Diffusion 0.001264 0.032066
# Intracellular Diffusion Intracellular $T_2$ 0.003270 0.030370
# Intracellular Diffusion Extracellular $T_2$ 0.002200 0.030499
# Intracellular Diffusion B-Value 0.002071 0.030655
# Intracellular Diffusion Diffusion Time 0.010691 0.030145
# Extracellular Diffusion Intracellular $T_2$ 0.004430 0.016168
# Extracellular Diffusion Extracellular $T_2$ 0.002004 0.016403
# Extracellular Diffusion B-Value 0.002883 0.016593
# Extracellular Diffusion Diffusion Time 0.004002 0.016712
# Intracellular $T_2$ Extracellular $T_2$ -0.000575 0.006644
# Intracellular $T_2$ B-Value -0.000659 0.006683
# Intracellular $T_2$ Diffusion Time -0.000908 0.006661
# Extracellular $T_2$ B-Value -0.000445 0.001379
# Extracellular $T_2$ Diffusion Time -0.000263 0.001386
# B-Value Diffusion Time 0.000129 0.003521
#
# _____________________________________________________________________________________
# Sensitivity Indices for RD
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.328573 0.026193 0.409253 0.024985
# Volume Fraction -0.000215 0.008755 0.051703 0.003256
# Permeability 0.060121 0.010383 0.072806 0.003659
# Intracellular Diffusion 0.353137 0.024944 0.441513 0.019870
# Extracellular Diffusion 0.092132 0.011688 0.122555 0.007480
# Intracellular $T_2$ 0.000258 0.003664 0.009619 0.000829
# Extracellular $T_2$ 0.000045 0.001113 0.000467 0.000042
# B-Value 0.001152 0.002119 0.002534 0.000225
# Diffusion Time 0.021936 0.007496 0.036681 0.002988
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.011809 0.029811
# Diameter Permeability 0.005337 0.033288
# Diameter Intracellular Diffusion 0.047243 0.034486
# Diameter Extracellular Diffusion 0.003445 0.031482
# Diameter Intracellular $T_2$ 0.003809 0.029601
# Diameter Extracellular $T_2$ 0.000700 0.029780
# Diameter B-Value 0.001013 0.029872
# Diameter Diffusion Time -0.000599 0.029183
# Volume Fraction Permeability 0.000667 0.014625
# Volume Fraction Intracellular Diffusion 0.009831 0.013741
# Volume Fraction Extracellular Diffusion 0.019850 0.015532
# Volume Fraction Intracellular $T_2$ -0.000058 0.014352
# Volume Fraction Extracellular $T_2$ 0.000254 0.014361
# Volume Fraction B-Value 0.000277 0.014197
# Volume Fraction Diffusion Time 0.000471 0.014393
# Permeability Intracellular Diffusion 0.007123 0.016671
# Permeability Extracellular Diffusion -0.003729 0.013359
# Permeability Intracellular $T_2$ -0.003231 0.012784
# Permeability Extracellular $T_2$ -0.003224 0.012796
# Permeability B-Value -0.002854 0.012741
# Permeability Diffusion Time -0.003381 0.013398
# Intracellular Diffusion Extracellular Diffusion -0.001600 0.034126
# Intracellular Diffusion Intracellular $T_2$ 0.001284 0.032287
# Intracellular Diffusion Extracellular $T_2$ 0.000254 0.032459
# Intracellular Diffusion B-Value -0.000102 0.032656
# Intracellular Diffusion Diffusion Time 0.009189 0.032335
# Extracellular Diffusion Intracellular $T_2$ 0.004923 0.017987
# Extracellular Diffusion Extracellular $T_2$ 0.002769 0.017697
# Extracellular Diffusion B-Value 0.003283 0.017554
# Extracellular Diffusion Diffusion Time 0.004130 0.017606
# Intracellular $T_2$ Extracellular $T_2$ -0.000511 0.005891
# Intracellular $T_2$ B-Value -0.000594 0.005880
# Intracellular $T_2$ Diffusion Time -0.000980 0.006029
# Extracellular $T_2$ B-Value -0.000349 0.001440
# Extracellular $T_2$ Diffusion Time -0.000200 0.001446
# B-Value Diffusion Time 0.000799 0.003102
#
# _____________________________________________________________________________________
# Sensitivity Indices for L1
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.117148 0.014353 0.148942 0.008643
# Volume Fraction -0.001758 0.008891 0.057716 0.004082
# Permeability 0.026685 0.007506 0.034484 0.002241
# Intracellular Diffusion 0.584766 0.028726 0.642828 0.029509
# Extracellular Diffusion 0.153551 0.015670 0.198221 0.011368
# Intracellular $T_2$ 0.000197 0.004044 0.009762 0.000855
# Extracellular $T_2$ 0.000002 0.000792 0.000463 0.000045
# B-Value 0.000970 0.001546 0.001899 0.000180
# Diffusion Time 0.006845 0.005733 0.020596 0.001861
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.003929 0.020173
# Diameter Permeability 0.002315 0.020526
# Diameter Intracellular Diffusion 0.013159 0.022292
# Diameter Extracellular Diffusion 0.003440 0.021137
# Diameter Intracellular $T_2$ 0.001169 0.019773
# Diameter Extracellular $T_2$ 0.000308 0.019947
# Diameter B-Value 0.000277 0.019927
# Diameter Diffusion Time 0.000004 0.019685
# Volume Fraction Permeability 0.000831 0.014127
# Volume Fraction Intracellular Diffusion 0.020826 0.013662
# Volume Fraction Extracellular Diffusion 0.028843 0.013570
# Volume Fraction Intracellular $T_2$ 0.000270 0.013657
# Volume Fraction Extracellular $T_2$ 0.000308 0.013662
# Volume Fraction B-Value 0.000359 0.013815
# Volume Fraction Diffusion Time 0.000751 0.013679
# Permeability Intracellular Diffusion 0.002651 0.012015
# Permeability Extracellular Diffusion -0.001568 0.011442
# Permeability Intracellular $T_2$ -0.001853 0.011546
# Permeability Extracellular $T_2$ -0.001785 0.011544
# Permeability B-Value -0.001408 0.011531
# Permeability Diffusion Time -0.002231 0.011505
# Intracellular Diffusion Extracellular Diffusion 0.000234 0.040707
# Intracellular Diffusion Intracellular $T_2$ 0.002740 0.035749
# Intracellular Diffusion Extracellular $T_2$ 0.000508 0.036001
# Intracellular Diffusion B-Value 0.000584 0.035966
# Intracellular Diffusion Diffusion Time 0.009042 0.037504
# Extracellular Diffusion Intracellular $T_2$ 0.007301 0.018171
# Extracellular Diffusion Extracellular $T_2$ 0.003790 0.018338
# Extracellular Diffusion B-Value 0.004528 0.018287
# Extracellular Diffusion Diffusion Time 0.006218 0.018335
# Intracellular $T_2$ Extracellular $T_2$ -0.001026 0.005347
# Intracellular $T_2$ B-Value -0.001075 0.005322
# Intracellular $T_2$ Diffusion Time -0.001187 0.005401
# Extracellular $T_2$ B-Value -0.000346 0.001371
# Extracellular $T_2$ Diffusion Time -0.000240 0.001378
# B-Value Diffusion Time 0.000234 0.002485
#
# _____________________________________________________________________________________
# Sensitivity Indices for L2
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.318238 0.022600 0.399157 0.024163
# Volume Fraction -0.000998 0.009597 0.051572 0.003892
# Permeability 0.061544 0.010260 0.074363 0.003942
# Intracellular Diffusion 0.359203 0.027543 0.449285 0.022785
# Extracellular Diffusion 0.096605 0.016521 0.126554 0.007598
# Intracellular $T_2$ 0.000161 0.003952 0.009603 0.000929
# Extracellular $T_2$ -0.000020 0.000859 0.000462 0.000042
# B-Value 0.001569 0.002334 0.002952 0.000247
# Diffusion Time 0.018426 0.007341 0.033185 0.002535
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.012870 0.031644
# Diameter Permeability 0.005696 0.033825
# Diameter Intracellular Diffusion 0.048816 0.036548
# Diameter Extracellular Diffusion 0.003168 0.031632
# Diameter Intracellular $T_2$ 0.003939 0.030967
# Diameter Extracellular $T_2$ 0.000886 0.031731
# Diameter B-Value 0.001010 0.031859
# Diameter Diffusion Time -0.000212 0.032163
# Volume Fraction Permeability 0.001328 0.012435
# Volume Fraction Intracellular Diffusion 0.010299 0.012966
# Volume Fraction Extracellular Diffusion 0.020185 0.014026
# Volume Fraction Intracellular $T_2$ 0.000667 0.012669
# Volume Fraction Extracellular $T_2$ 0.000929 0.012559
# Volume Fraction B-Value 0.000866 0.012507
# Volume Fraction Diffusion Time 0.000933 0.012658
# Permeability Intracellular Diffusion 0.007591 0.015993
# Permeability Extracellular Diffusion -0.004172 0.014053
# Permeability Intracellular $T_2$ -0.003669 0.013579
# Permeability Extracellular $T_2$ -0.003569 0.013503
# Permeability B-Value -0.003220 0.013490
# Permeability Diffusion Time -0.003722 0.013550
# Intracellular Diffusion Extracellular Diffusion -0.000159 0.037083
# Intracellular Diffusion Intracellular $T_2$ 0.002291 0.035504
# Intracellular Diffusion Extracellular $T_2$ 0.001244 0.035440
# Intracellular Diffusion B-Value 0.001003 0.035272
# Intracellular Diffusion Diffusion Time 0.009953 0.035786
# Extracellular Diffusion Intracellular $T_2$ 0.004693 0.020170
# Extracellular Diffusion Extracellular $T_2$ 0.002403 0.020700
# Extracellular Diffusion B-Value 0.003098 0.020677
# Extracellular Diffusion Diffusion Time 0.004068 0.021706
# Intracellular $T_2$ Extracellular $T_2$ -0.000536 0.005750
# Intracellular $T_2$ B-Value -0.000621 0.005731
# Intracellular $T_2$ Diffusion Time -0.000945 0.005847
# Extracellular $T_2$ B-Value -0.000391 0.001355
# Extracellular $T_2$ Diffusion Time -0.000228 0.001348
# B-Value Diffusion Time 0.000461 0.003512
#
# _____________________________________________________________________________________
# Sensitivity Indices for L3
# Parameter S1 S1_conf ST ST_conf
# Diameter -0.000550 0.003875 0.012055 0.001274
# Volume Fraction -0.001028 0.010822 0.064109 0.003922
# Permeability 0.000934 0.002887 0.005518 0.000633
# Intracellular Diffusion 0.714177 0.030374 0.766764 0.025061
# Extracellular Diffusion 0.183256 0.018628 0.235763 0.010356
# Intracellular $T_2$ -0.000035 0.004282 0.011086 0.001164
# Extracellular $T_2$ -0.000021 0.000858 0.000515 0.000050
# B-Value 0.000058 0.001254 0.001206 0.000158
# Diffusion Time 0.000565 0.004253 0.011274 0.001370
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction -0.000479 0.006120
# Diameter Permeability -0.000754 0.006261
# Diameter Intracellular Diffusion 0.005570 0.006159
# Diameter Extracellular Diffusion 0.003696 0.005800
# Diameter Intracellular $T_2$ -0.000435 0.006229
# Diameter Extracellular $T_2$ -0.000366 0.006198
# Diameter B-Value -0.000277 0.006209
# Diameter Diffusion Time -0.000366 0.006124
# Volume Fraction Permeability 0.001270 0.014048
# Volume Fraction Intracellular Diffusion 0.032412 0.015111
# Volume Fraction Extracellular Diffusion 0.032433 0.015431
# Volume Fraction Intracellular $T_2$ 0.000994 0.014059
# Volume Fraction Extracellular $T_2$ 0.000785 0.014055
# Volume Fraction B-Value 0.000944 0.014042
# Volume Fraction Diffusion Time 0.001090 0.014074
# Permeability Intracellular Diffusion -0.000160 0.004718
# Permeability Extracellular Diffusion 0.003161 0.004154
# Permeability Intracellular $T_2$ 0.001404 0.004552
# Permeability Extracellular $T_2$ 0.001309 0.004559
# Permeability B-Value 0.001520 0.004539
# Permeability Diffusion Time 0.001102 0.004595
# Intracellular Diffusion Extracellular Diffusion 0.002789 0.044666
# Intracellular Diffusion Intracellular $T_2$ 0.004501 0.037301
# Intracellular Diffusion Extracellular $T_2$ 0.000697 0.038239
# Intracellular Diffusion B-Value 0.001449 0.038294
# Intracellular Diffusion Diffusion Time 0.005342 0.037774
# Extracellular Diffusion Intracellular $T_2$ 0.009464 0.025886
# Extracellular Diffusion Extracellular $T_2$ 0.005253 0.026327
# Extracellular Diffusion B-Value 0.005804 0.026234
# Extracellular Diffusion Diffusion Time 0.007862 0.026392
# Intracellular $T_2$ Extracellular $T_2$ -0.001423 0.005731
# Intracellular $T_2$ B-Value -0.001376 0.005751
# Intracellular $T_2$ Diffusion Time -0.001539 0.005657
# Extracellular $T_2$ B-Value -0.000292 0.001219
# Extracellular $T_2$ Diffusion Time -0.000310 0.001223
# B-Value Diffusion Time 0.000002 0.001992
#
# _____________________________________________________________________________________

# %%
"""
This cell generates the sensitivity indices for the generalized diffusion-weighted sequence. 
The raw data is located in 'sensitivity_results-genDW.csv' and the imported dataframe contains 
other informatino regarding the numerical parameters used in the simulation. 
"""


problem_genDW = { 'num_vars': 7,

           'bounds': [[10e-6, 80e-6 ], # diameter
                      [0.70  , 0.95  ], # volume fraction
                      [10e-6 , 100e-6], # permeability
                      [0.5e-9, 2.5e-9], # Din
                      [0.5e-9, 2.5e-9], # Dex
                      [300e6 , 1200e6],  # b-value
                      [0.0100, 0.750]],   # Diffusion Time

            'names': ['Diameter', 
                        'Volume Fraction', 
                        'Permeability', 
                        'Intracellular Diffusion', 
                        'Extracellular Diffusion', 
                        'B-Value',
                        'Diffusion Time']
            }

param_values = saltelli.sample(problem_genDW, 5000)

filename = 'sensitivity_results-genDW.csv'
df = pd.read_csv(filename,header=[0, 1], skipinitialspace=True)
DTI_indices = df['DTI Metrics'][['FA','MD','RD','L1','L2','L3']]

Si_genDW = { }
for i, j in enumerate( DTI_indices.columns):
    print('Sensitivity Indices for %s' % j)
    Si_genDW[j] = sobol.analyze(problem_genDW, DTI_indices.values[:,i], print_to_console=True)
    print(' ')
    print('_____________________________________________________________________________________')
# Out:
# Sensitivity Indices for FA
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.422523 0.027850 0.448926 0.019247
# Volume Fraction 0.017533 0.005099 0.021970 0.000988
# Permeability 0.257629 0.020421 0.280347 0.012277
# Intracellular Diffusion 0.213038 0.015423 0.231863 0.011035
# Extracellular Diffusion 0.000854 0.002468 0.003766 0.000239
# B-Value -0.000162 0.001341 0.001053 0.000090
# Diffusion Time 0.040951 0.011404 0.063947 0.007069
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.000695 0.035957
# Diameter Permeability 0.003203 0.036737
# Diameter Intracellular Diffusion 0.006208 0.039268
# Diameter Extracellular Diffusion -0.000170 0.035757
# Diameter B-Value 0.000592 0.035827
# Diameter Diffusion Time 0.005715 0.035657
# Volume Fraction Permeability -0.000450 0.008901
# Volume Fraction Intracellular Diffusion -0.000261 0.007754
# Volume Fraction Extracellular Diffusion -0.001414 0.007246
# Volume Fraction B-Value -0.001326 0.007286
# Volume Fraction Diffusion Time 0.000126 0.007227
# Permeability Intracellular Diffusion 0.006236 0.029737
# Permeability Extracellular Diffusion 0.003998 0.027632
# Permeability B-Value 0.003620 0.027468
# Permeability Diffusion Time 0.012504 0.028494
# Intracellular Diffusion Extracellular Diffusion 0.000371 0.021021
# Intracellular Diffusion B-Value -0.001305 0.020534
# Intracellular Diffusion Diffusion Time 0.001713 0.021307
# Extracellular Diffusion B-Value -0.000781 0.004437
# Extracellular Diffusion Diffusion Time -0.000039 0.004541
# B-Value Diffusion Time 0.001114 0.001939
#
# _____________________________________________________________________________________
# Sensitivity Indices for MD
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.337060 0.022261 0.396802 0.017851
# Volume Fraction 0.015673 0.007007 0.026396 0.001518
# Permeability 0.220562 0.018966 0.260841 0.013017
# Intracellular Diffusion 0.239012 0.023786 0.314418 0.016987
# Extracellular Diffusion 0.042455 0.008297 0.052232 0.002805
# B-Value -0.000376 0.001645 0.001709 0.000150
# Diffusion Time 0.034581 0.011085 0.061408 0.006951
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.003187 0.032793
# Diameter Permeability 0.004203 0.035639
# Diameter Intracellular Diffusion 0.039708 0.036568
# Diameter Extracellular Diffusion 0.003836 0.033427
# Diameter B-Value 0.003371 0.032107
# Diameter Diffusion Time 0.007836 0.033512
# Volume Fraction Permeability -0.001182 0.010844
# Volume Fraction Intracellular Diffusion -0.002446 0.009479
# Volume Fraction Extracellular Diffusion 0.005262 0.010612
# Volume Fraction B-Value -0.002176 0.009995
# Volume Fraction Diffusion Time -0.001059 0.009933
# Permeability Intracellular Diffusion 0.027908 0.027210
# Permeability Extracellular Diffusion 0.006854 0.025233
# Permeability B-Value 0.006996 0.024825
# Permeability Diffusion Time 0.012613 0.024130
# Intracellular Diffusion Extracellular Diffusion -0.006063 0.029466
# Intracellular Diffusion B-Value -0.006752 0.028839
# Intracellular Diffusion Diffusion Time 0.002123 0.030702
# Extracellular Diffusion B-Value 0.000303 0.010041
# Extracellular Diffusion Diffusion Time 0.001142 0.010780
# B-Value Diffusion Time 0.001243 0.002518
#
# _____________________________________________________________________________________
# Sensitivity Indices for RD
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.361803 0.021508 0.420926 0.019928
# Volume Fraction 0.019031 0.006651 0.028299 0.001585
# Permeability 0.210302 0.021076 0.246757 0.013008
# Intracellular Diffusion 0.223468 0.020735 0.297127 0.019327
# Extracellular Diffusion 0.036104 0.008199 0.045188 0.002780
# B-Value -0.000510 0.000973 0.000782 0.000068
# Diffusion Time 0.043443 0.011663 0.071472 0.007252
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.001625 0.030646
# Diameter Permeability 0.002727 0.033983
# Diameter Intracellular Diffusion 0.039586 0.034082
# Diameter Extracellular Diffusion 0.002756 0.030009
# Diameter B-Value 0.001998 0.029620
# Diameter Diffusion Time 0.007196 0.031172
# Volume Fraction Permeability -0.002442 0.010414
# Volume Fraction Intracellular Diffusion -0.003413 0.008661
# Volume Fraction Extracellular Diffusion 0.004672 0.008832
# Volume Fraction B-Value -0.002472 0.008373
# Volume Fraction Diffusion Time -0.001040 0.008408
# Permeability Intracellular Diffusion 0.025049 0.029088
# Permeability Extracellular Diffusion 0.006373 0.026431
# Permeability B-Value 0.006604 0.026323
# Permeability Diffusion Time 0.012007 0.025642
# Intracellular Diffusion Extracellular Diffusion -0.005402 0.027915
# Intracellular Diffusion B-Value -0.005839 0.027862
# Intracellular Diffusion Diffusion Time 0.004361 0.029695
# Extracellular Diffusion B-Value 0.000405 0.011007
# Extracellular Diffusion Diffusion Time 0.001202 0.011677
# B-Value Diffusion Time 0.001006 0.001576
#
# _____________________________________________________________________________________
# Sensitivity Indices for L1
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.133371 0.015940 0.156078 0.008609
# Volume Fraction 0.006550 0.005331 0.019899 0.001251
# Permeability 0.082555 0.012392 0.098217 0.005290
# Intracellular Diffusion 0.659400 0.029221 0.688891 0.026909
# Extracellular Diffusion 0.052018 0.009449 0.062716 0.003598
# B-Value -0.000300 0.000792 0.000475 0.000063
# Diffusion Time 0.013138 0.007218 0.023456 0.002529
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.001826 0.020697
# Diameter Permeability 0.002382 0.023308
# Diameter Intracellular Diffusion 0.014654 0.024118
# Diameter Extracellular Diffusion 0.002609 0.021680
# Diameter B-Value 0.001968 0.020847
# Diameter Diffusion Time 0.003402 0.020953
# Volume Fraction Permeability -0.001699 0.008191
# Volume Fraction Intracellular Diffusion 0.000475 0.008127
# Volume Fraction Extracellular Diffusion 0.007429 0.008624
# Volume Fraction B-Value -0.002174 0.008092
# Volume Fraction Diffusion Time -0.001805 0.008276
# Permeability Intracellular Diffusion 0.011093 0.020022
# Permeability Extracellular Diffusion 0.004776 0.017340
# Permeability B-Value 0.005003 0.016561
# Permeability Diffusion Time 0.007036 0.016321
# Intracellular Diffusion Extracellular Diffusion -0.003651 0.037245
# Intracellular Diffusion B-Value -0.004272 0.033438
# Intracellular Diffusion Diffusion Time -0.000466 0.034623
# Extracellular Diffusion B-Value 0.000430 0.013756
# Extracellular Diffusion Diffusion Time 0.000978 0.013965
# B-Value Diffusion Time 0.000479 0.001117
#
# _____________________________________________________________________________________
# Sensitivity Indices for L2
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.349450 0.024606 0.408756 0.024302
# Volume Fraction 0.017306 0.005902 0.027176 0.001318
# Permeability 0.215621 0.020327 0.253963 0.012370
# Intracellular Diffusion 0.231433 0.022607 0.305922 0.018519
# Extracellular Diffusion 0.039281 0.007757 0.048682 0.002846
# B-Value -0.000463 0.001231 0.001183 0.000110
# Diffusion Time 0.038866 0.011153 0.066241 0.006817
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction 0.002320 0.030883
# Diameter Permeability 0.003448 0.033700
# Diameter Intracellular Diffusion 0.039674 0.032417
# Diameter Extracellular Diffusion 0.003297 0.031320
# Diameter B-Value 0.002682 0.029226
# Diameter Diffusion Time 0.007502 0.032412
# Volume Fraction Permeability -0.001810 0.009572
# Volume Fraction Intracellular Diffusion -0.002928 0.009324
# Volume Fraction Extracellular Diffusion 0.004981 0.009429
# Volume Fraction B-Value -0.002318 0.008901
# Volume Fraction Diffusion Time -0.001054 0.008654
# Permeability Intracellular Diffusion 0.026481 0.032687
# Permeability Extracellular Diffusion 0.006611 0.030375
# Permeability B-Value 0.006797 0.029951
# Permeability Diffusion Time 0.012313 0.031008
# Intracellular Diffusion Extracellular Diffusion -0.005746 0.032778
# Intracellular Diffusion B-Value -0.006318 0.031904
# Intracellular Diffusion Diffusion Time 0.003217 0.033188
# Extracellular Diffusion B-Value 0.000350 0.010533
# Extracellular Diffusion Diffusion Time 0.001167 0.010917
# B-Value Diffusion Time 0.001118 0.002045
#
# _____________________________________________________________________________________
# Sensitivity Indices for L3
# Parameter S1 S1_conf ST ST_conf
# Diameter 0.000082 0.000645 0.000358 0.000034
# Volume Fraction 0.000824 0.004109 0.014400 0.001037
# Permeability -0.000081 0.000378 0.000098 0.000018
# Intracellular Diffusion 0.945592 0.029098 0.953530 0.030798
# Extracellular Diffusion 0.039305 0.007920 0.047069 0.002600
# B-Value 0.000000 0.000513 0.000201 0.000058
# Diffusion Time -0.000125 0.000703 0.000524 0.000114
#
# Parameter_1 Parameter_2 S2 S2_conf
# Diameter Volume Fraction -0.000294 0.000974
# Diameter Permeability -0.000171 0.000997
# Diameter Intracellular Diffusion 0.000172 0.001139
# Diameter Extracellular Diffusion -0.000171 0.001029
# Diameter B-Value -0.000185 0.000997
# Diameter Diffusion Time -0.000130 0.000997
# Volume Fraction Permeability -0.001704 0.007595
# Volume Fraction Intracellular Diffusion 0.005610 0.007368
# Volume Fraction Extracellular Diffusion 0.005390 0.007954
# Volume Fraction B-Value -0.001679 0.007600
# Volume Fraction Diffusion Time -0.001723 0.007581
# Permeability Intracellular Diffusion 0.000106 0.000629
# Permeability Extracellular Diffusion -0.000004 0.000550
# Permeability B-Value -0.000031 0.000563
# Permeability Diffusion Time -0.000027 0.000565
# Intracellular Diffusion Extracellular Diffusion -0.000310 0.036615
# Intracellular Diffusion B-Value -0.000759 0.034265
# Intracellular Diffusion Diffusion Time -0.000470 0.034409
# Extracellular Diffusion B-Value 0.000732 0.011067
# Extracellular Diffusion Diffusion Time 0.000711 0.011036
# B-Value Diffusion Time 0.000053 0.000831
#
# _____________________________________________________________________________________
